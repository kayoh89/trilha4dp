# %%
#Import das bibliotecas
import tensorflow as tf 
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/suicidios_por_estados_por_ano.csv" ,index_col=0)

# %%
df.head()
# Out:
#   abrev_estado    estado  regiao   ano   n
# 1           RO  Rondônia       1  2010  82
# 2           RO  Rondônia       1  2011  78
# 3           RO  Rondônia       1  2012  73
# 4           RO  Rondônia       1  2013  86
# 5           RO  Rondônia       1  2014  84

# %%
#Verificando se há valores nulos.
print(df.isnull().sum())
# Out:
# abrev_estado    0
# estado          0
# regiao          0
# ano             0
# n               0
# dtype: int64

# %%
df
# Out:
#     abrev_estado            estado  regiao   ano    n
# 1             RO          Rondônia       1  2010   82
# 2             RO          Rondônia       1  2011   78
# 3             RO          Rondônia       1  2012   73
# 4             RO          Rondônia       1  2013   86
# 5             RO          Rondônia       1  2014   84
# ..           ...               ...     ...   ...  ...
# 266           DF  Distrito Federal       4  2015  131
# 267           DF  Distrito Federal       4  2016  153
# 268           DF  Distrito Federal       4  2017  169
# 269           DF  Distrito Federal       4  2018  188
# 270           DF  Distrito Federal       4  2019  201
#
# [270 rows x 5 columns]

# %%
# EXPLORAÇÃO DOS DADOS
df['regiao'].value_counts()
# Out:
# 2    90
# 1    70
# 4    40
# 3    40
# 5    30
# Name: regiao, dtype: int64

# %%
#dropando colunas 
df = df.drop(["abrev_estado",'estado'], axis=1)

# %%
 # Converter o tipo de dados para float 
df = df.astype (float)

# %%
X = df.drop('regiao', axis=1)
y = df[['regiao']]

# %%
# Normalização dos dados
# A normalização é necessária, já que os valores podem apresentar escalas muito
# diferentes e podemos então completar a nossa entrada de dados X.

from sklearn.preprocessing import scale

X = scale(X)
X
# Out:
# array([[-1.5666989 , -0.69956744],
#        [-1.21854359, -0.70792964],
#        [-0.87038828, -0.71838238],
#        [-0.52223297, -0.69120524],
#        [-0.17407766, -0.69538634],
#        [ 0.17407766, -0.64103206],
#        [ 0.52223297, -0.65566591],
#        [ 0.87038828, -0.63476041],
#        [ 1.21854359, -0.60758328],
#        [ 1.5666989 , -0.57831559],
#        [-1.5666989 , -0.78527996],
#        [-1.21854359, -0.78527996],
#        [-0.87038828, -0.78109886],
#        [-0.52223297, -0.77900831],
#        [-0.17407766, -0.76855556],
#        [ 0.17407766, -0.78946105],
#        [ 0.52223297, -0.75392172],
#        [ 0.87038828, -0.73719732],
#        [ 1.21854359, -0.74765007],
#        [ 1.5666989 , -0.72047293],
#        [-1.5666989 , -0.53232351],
#        [-1.21854359, -0.47796923],
#        [-0.87038828, -0.48424087],
#        [-0.52223297, -0.40061891],
#        [-0.17407766, -0.38389451],
#        [ 0.17407766, -0.32117804],
#        [ 0.52223297, -0.46333538],
#        [ 0.87038828, -0.43824879],
#        [ 1.21854359, -0.38180396],
#        [ 1.5666989 , -0.34208353],
#        [-1.5666989 , -0.7999138 ],
#        [-1.21854359, -0.7999138 ],
#        [-0.87038828, -0.7915516 ],
#        [-0.52223297, -0.80200435],
#        [ 0.87038828, -0.51768966],
#        [ 1.21854359, -0.47796923],
#        [ 1.5666989 , -0.45079209]])

# %%
df.head()
# Out:
#    regiao     ano     n
# 1     1.0  2010.0  82.0
# 2     1.0  2011.0  78.0
# 3     1.0  2012.0  73.0
# 4     1.0  2013.0  86.0
# 5     1.0  2014.0  84.0

# %%
# Definidos e tratados os dados de entrada X e saída y do nosso conjunto de
# exemplos, podemos então separar os conjuntos de treinamento e teste.

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=123)

# %%
display(X_train)
display(y_train)
# Out:
# array([[-0.17407766, -0.7999138 ],
#        [ 1.5666989 ,  2.11013065],
#        [-1.21854359,  0.21818365],
#        [ 0.17407766, -0.76228391],
#        [-0.52223297, -0.60758328],
#        [-0.52223297, -0.60967382],
#        [ 0.87038828, -0.60340218],
#        [ 0.17407766,  0.24745134],
#        [-1.21854359, -0.5406857 ],
#        [-1.5666989 , -0.808276  ],
#        [ 0.52223297,  0.53803767],
#        [ 0.52223297,  1.58122171],
#        [-0.17407766, -0.58249669],
#        [ 0.87038828, -0.51768966],
#        [ 1.5666989 ,  0.79935632],
#        [ 1.21854359,  0.17637267],
#        [ 0.17407766,  1.8613553 ],
#        [ 1.5666989 , -0.35253628],
#        [-0.17407766, -0.53859515],
#        [-1.21854359, -0.40689055],
#        [-0.17407766,  0.22236475],
#        [-1.21854359,  0.03421532],
#        [-0.52223297, -0.77900831],
#        [ 0.87038828, -0.63476041],
#        [-1.5666989 ,  3.24529886],
#        [ 0.87038828, -0.49469362],
#        [-1.5666989 ,  1.29690702],
#        [ 0.87038828,  0.39588033],
#        [-0.87038828, -0.17274905],
#        [-0.52223297,  0.51086053],
#        [-0.52223297,  1.52059579],
#        [ 0.52223297, -0.63685096],
#        [ 0.87038828,  2.29618953],
#        [ 1.5666989 , -0.36507957],
#        [ 1.21854359, -0.60758328],
#        [ 0.87038828, -0.20201674],
#        [-0.52223297, -0.5365046 ],
#        [-0.87038828,  0.28090012],
#        [-1.21854359, -0.60967382],
#        [ 1.5666989 ,  2.76029145],
#        [ 1.21854359,  0.67183282],
#        [-0.17407766, -0.64103206],
#        [-0.52223297,  1.55404457],
#        [ 0.87038828, -0.45915428],
#        [-0.87038828, -0.47587868],
#        [ 1.5666989 , -0.34626463],
#        [ 0.52223297, -0.74765007],
#        [ 0.87038828, -0.32954024],
#        [-0.52223297, -0.67029975],
#        [ 1.21854359, -0.46124483],
#        [ 1.21854359, -0.17902069],
#        [-1.21854359,  3.41463334],
#        [-0.17407766, -0.43615824],
#        [ 0.17407766, -0.47378813],
#        [ 0.52223297,  0.73245875],
#        [ 0.17407766, -0.6640281 ],
#        [-1.5666989 , -0.6849336 ],
#        [-0.52223297,  0.36452209],
#        [-0.52223297, -0.39016616],
#        [ 0.17407766, -0.56786284],
#        [-0.87038828, -0.47796923],
#        [-1.5666989 , -0.69956744],
#        [ 0.17407766, -0.31281584],
#        [-1.5666989 , -0.47796923],
#        [ 1.5666989 , -0.73928787],
#        [ 0.87038828,  0.75336424],
#        [ 0.52223297, -0.29191035],
#        [ 0.17407766, -0.39016616],
#        [-0.87038828,  0.4585968 ],
#        [-0.17407766, -0.51559911],
#        [-0.52223297, -0.57204394],
#        [ 0.52223297, -0.75392172],
#        [ 0.52223297, -0.40480001],
#        [ 0.52223297,  0.24117969],
#        [ 0.52223297, -0.49260307],
#        [-1.21854359, -0.42779605],
#        [-0.17407766, -0.33581188],
#        [-1.5666989 , -0.5406857 ],
#        [ 0.17407766, -0.62012657],
#        [ 1.21854359, -0.79364215],
#        [ 0.87038828, -0.43824879],
#        [-1.5666989 , -0.59922108],
#        [-1.21854359, -0.25846156],
#        [ 1.21854359,  3.75121176],
#        [ 0.87038828, -0.20828838],
#        [ 1.5666989 , -0.57831559],
#        [ 0.52223297, -0.65566591],
#        [-1.5666989 , -0.52814241],
#        [-0.17407766,  0.08647905],
#        [-0.17407766, -0.44452044],
#        [ 1.5666989 , -0.45079209],
#        [ 0.87038828,  3.94981393],
#        [ 1.5666989 , -0.62848877],
#        [ 1.5666989 , -0.60131163],
#        [ 0.87038828, -0.63057932],
#        [-0.52223297, -0.69120524],
#        [ 0.52223297, -0.19992619],
#        [ 0.87038828, -0.43824879],
#        [ 1.21854359,  0.5944825 ],
#        [ 1.21854359, -0.13720971],
#        [ 0.87038828, -0.34835518],
#        [-0.87038828, -0.49469362],
#        [-1.21854359, -0.78946105],
#        [-1.21854359, -0.70792964],
#        [ 1.21854359, -0.74765007],
#        [-0.87038828, -0.78109886],
#        [-0.17407766, -0.54277625],
#        [ 0.52223297, -0.7957327 ],
#        [ 1.21854359, -0.37135122],
#        [ 0.17407766, -0.32117804],
#        [-0.52223297,  0.05512081],
#        [-1.21854359, -0.50096527],
#        [ 0.52223297,  0.32689221],
#        [-0.52223297, -0.38389451],
#        [ 1.5666989 ,  0.05512081],
#        [-0.87038828,  0.10320344],
#        [-0.52223297, -0.5406857 ],
#        [-0.17407766, -0.76855556],
#        [-0.17407766, -0.62430767],
#        [-0.17407766,  0.06766411],
#        [ 0.17407766, -0.4089811 ],
#        [ 1.5666989 , -0.44452044],
#        [-1.5666989 , -0.43406769],
#        [ 1.21854359,  1.72337906],
#        [ 1.21854359,  0.30807726],
#        [-0.87038828,  1.60003665],
#        [ 0.17407766, -0.78946105],
#        [ 0.52223297, -0.63057932],
#        [ 0.17407766,  0.63420294],
#        [-0.87038828, -0.48424087],
#        [ 1.21854359, -0.58458723],
#        [ 1.21854359, -0.74137842],
#        [-0.87038828,  1.77355224],
#        [ 0.17407766, -0.27936705],
#        [-0.17407766, -0.69329579],
#        [ 1.5666989 , -0.59085888],
#        [ 0.17407766, -0.59713053],
#        [-1.21854359, -0.65357536],
#        [ 1.21854359,  2.33381942],
#        [ 0.52223297, -0.25637101],
#        [-0.17407766, -0.83963423],
#        [ 0.17407766,  0.18264431],
#        [-0.17407766,  0.31643946],
#        [ 1.21854359, -0.37553232],
#        [-0.52223297,  0.31853001],
#        [ 0.87038828,  0.47741175],
#        [-0.87038828, -0.50723692],
#        [-1.5666989 ,  0.19936871],
#        [-0.87038828,  0.19727816],
#        [-0.17407766, -0.18947344],
#        [ 1.5666989 ,  0.44605351],
#        [ 0.17407766, -0.5448668 ],
#        [ 0.17407766, -0.62848877],
#        [ 0.52223297, -0.50514637],
#        [ 1.5666989 ,  0.32689221],
#        [ 0.87038828,  0.17010102],
#        [-1.5666989 , -0.53023296],
#        [ 0.52223297, -0.65984701],
#        [ 1.5666989 , -0.76646501],
#        [-0.17407766, -0.36089847],
#        [-0.87038828, -0.71838238],
#        [ 0.17407766,  3.94145173],
#        [ 0.17407766, -0.76019337],
#        [ 1.5666989 , -0.14348136],
#        [ 1.21854359, -0.61176437],
#        [ 1.21854359,  1.05440332],
#        [-1.5666989 , -0.56159119],
#        [-0.17407766,  1.97006386],
#        [ 1.21854359, -0.21665058],
#        [ 0.52223297, -0.55113845],
#        [-0.52223297,  0.15964827],
#        [-1.21854359, -0.53023296],
#        [-0.17407766,  1.45578876],
#        [-0.17407766, -0.51141801],
#        [-0.87038828, -0.7915516 ],
#        [-0.52223297, -0.36298902],
#        [ 0.87038828, -0.23337497],
#        [ 0.52223297, -0.03686335],
#        [-0.52223297, -0.45288264],
#        [ 0.52223297,  0.36452209],
#        [ 0.17407766,  1.51641469],
#        [-0.17407766,  0.35825044],
#        [ 0.87038828, -0.77482721],
#        [-0.52223297, -0.19783564],
#        [ 0.52223297, -0.49260307],
#        [-0.52223297, -0.39434726],
#        [ 0.87038828, -0.73719732],
#        [-1.5666989 , -0.47796923],
#        [ 1.21854359,  0.50249834]])
#      regiao
# 55      1.0
# 230     5.0
# 212     5.0
# 36      1.0
# 264     4.0
# ..      ...
# 107     2.0
# 84      2.0
# 18      1.0
# 231     4.0
# 99      2.0
#
# [189 rows x 1 columns]

# %%
# !pip install -q -U keras-tuner

# %%
import kerastuner as kt

# %%
# imports
#-------------------------------------------------------------------------------

from tensorflow import keras
from tensorflow.keras import layers
import tensorflow as tf
from keras.layers import Dropout

# Define o Modelo
#-------------------------------------------------------------------------------

def model_builder(hp):

  # Hiperparâmetros do modelo
  #----------------------------------------------------------------------------- 
  hp_units_1 = hp.Int('hp_units_1', min_value=4, max_value=64, step=4)
  hp_drop_out = hp.Choice('Dropout', values=[0.05, 0.10, 0.15, 0.20])
  hp_activaton_out = hp.Choice('activation', values=['sigmoid','tanh'])

  # Hiperparâmetros do algoritmo
  #----------------------------------------------------------------------------- 
  hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])

  model = keras.Sequential(layers.Dense(units=hp_units_1, activation='relu', input_shape=[X.shape[1]]))
  model.add(Dropout(hp_drop_out))
  model.add(layers.Dense(1, activation=hp_activaton_out))
  
# Compila o Modelo
#-------------------------------------------------------------------------------

  model.compile(keras.optimizers.Adam(learning_rate=hp_learning_rate), 
                loss='binary_crossentropy', 
                metrics=['binary_accuracy'])

  return model

# %%
# Instancia o Tuner
#-------------------------------------------------------------------------------

tuner = kt.Hyperband(model_builder,
                     objective='val_binary_accuracy',
                     max_epochs=50,
                     factor=3,
                     directory='mydir',
                     project_name='regioes')

stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_binary_accuracy', patience=5)
# Out:
# INFO:tensorflow:Reloading Oracle from existing project mydir/regioes/oracle.json
# INFO:tensorflow:Reloading Oracle from existing project mydir/regioes/oracle.json
# INFO:tensorflow:Reloading Tuner from mydir/regioes/tuner0.json
# INFO:tensorflow:Reloading Tuner from mydir/regioes/tuner0.json

# %%
tuner.search(X_train, y_train, 
             batch_size=8,
             epochs=50, 
             validation_split=0.2, 
             callbacks=[stop_early])

# Get the optimal hyperparameters
best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]
# Out:
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit

# %%
print(f"""
The hyperparameter search is complete.

The optimal hp_units_1 for de optimizer is {best_hps.get('hp_units_1')} 
The optimal Dropout for the optimizer is {best_hps.get('Dropout')} 
The optimal activation for the optimizer is {best_hps.get('activation')}
The optimal learning_rate for the optimizer is {best_hps.get('learning_rate')}
""")
# Out:
# The hyperparameter search is complete.
#
# The optimal hp_units_1 for de optimizer is 12
# The optimal Dropout for the optimizer is 0.15
# The optimal activation for the optimizer is sigmoid
# The optimal learning_rate for the optimizer is 0.01

# %%
model = tuner.hypermodel.build(best_hps)

history = model.fit(X_train, y_train, 
                    batch_size=8,
                    epochs=50, 
                    validation_split=0.2,
                    verbose=0)

val_acc_per_epoch = history.history['val_binary_accuracy']
best_epoch = val_acc_per_epoch.index(max(val_acc_per_epoch)) + 1
print('Best epoch: %d' % (best_epoch,))
# Out:
# Best epoch: 1

# %%
hypermodel = tuner.hypermodel.build(best_hps)

# Retrain the model
hypermodel.fit(X_train, y_train, 
               batch_size=8,
               epochs=best_epoch,
               validation_split=0.2)
# Out:
# 19/19 [==============================] - 1s 12ms/step - loss: -0.7308 - binary_accuracy: 0.2583 - val_loss: -1.6766 - val_binary_accuracy: 0.2632

# %%
eval_result = hypermodel.evaluate(X_test, y_test)
print("[test loss, test accuracy]:", eval_result)
# Out:
# 3/3 [==============================] - 0s 4ms/step - loss: -2.0649 - binary_accuracy: 0.2593
# [test loss, test accuracy]: [-2.0649240016937256, 0.25925925374031067]

# %%
def display_hist(history):
  history_df = pd.DataFrame(history.history)
  display(history_df.head())
  # Start the plot at epoch 0
  history_df.loc[0:, ['loss', 'val_loss']].plot()
  history_df.loc[0:, ['binary_accuracy', 'val_binary_accuracy']].plot()

  print(("Best Validation Loss: {:0.4f}" +\
      "\nBest Validation Accuracy: {:0.4f}")\
      .format(history_df['val_loss'].min(), 
              history_df['val_binary_accuracy'].max()))
  return

# %%
display_hist(history)
# Out:
#         loss  binary_accuracy   val_loss  val_binary_accuracy
# 0  -1.232362         0.258278  -3.680296             0.263158
# 1  -6.717138         0.258278 -10.999377             0.263158
# 2 -16.396429         0.258278 -24.001408             0.263158
# 3 -33.117275         0.258278 -44.935585             0.263158
# 4 -59.979633         0.258278 -73.744278             0.263158
# Best Validation Loss: -12081.0693
# Best Validation Accuracy: 0.2632

# %%
# Avalia o Modelo
#-------------------------------------------------------------------------------
y_pred = hypermodel.predict(X_test) > 0.5 # classes binárias, retorna a probabilidade de ser 1, então > 0.5 é classe 1, senão é classe 0

# %%
# Avalia o Modelo
#-------------------------------------------------------------------------------
x_pred = hypermodel.predict(X_test) > 0.5 # classes binárias, retorna a probabilidade de ser 1, então > 0.5 é classe 1, senão é classe 0

# %% [markdown]
# Não houve uma otimização na acuracidade, acredito que devido ao dataset escolhido.
